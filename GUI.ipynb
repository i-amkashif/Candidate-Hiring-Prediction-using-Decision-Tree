# %%
import tkinter as tk
import numpy as np
import pandas as pd
from sklearn import tree

master = tk.Tk()

master.geometry("500x200")
master.wm_title("Decision Tree")


df = pd.read_csv("C:\\Users\\LENOVO\\Desktop\\ML\\DMBI\\MY_DT\\PastHires.csv")

df.head(10)


d = {'Y': 1, 'N': 0}
df['Hired'] = df['Hired'].map(d)
df['Employed?'] = df['Employed?'].map(d)
df['Top-tier school'] = df['Top-tier school'].map(d)
df['Interned'] = df['Interned'].map(d)
d = {'BS': 0, 'MS': 1, 'PhD': 2}
df['Level of Education'] = df['Level of Education'].map(d)
df.head()



features = list(df.columns[:6])
features


y = df["Hired"]
X = df[features]
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X,y)


#split and test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 50)


X_train.shape, X_test.shape


import category_encoders as ce

encoder = ce.OrdinalEncoder(cols=['Years Experience', 'Employed?', 'Previous employers', 'Level of Education', 'Top-tier school', 'Interned'])


X_train = encoder.fit_transform(X_train)

X_test = encoder.transform(X_test)

X_train.head()

X_test.head()


# import DecisionTreeClassifier

from sklearn.tree import DecisionTreeClassifier

clf_gini = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=0)


clf_gini.fit(X_train, y_train)

y_pred_gini = clf_gini.predict(X_test)

from sklearn.metrics import accuracy_score

print('Model accuracy score with criterion gini index: {0:0.4f}'. format(accuracy_score(y_test, y_pred_gini)))


y_pred_train_gini = clf_gini.predict(X_train)

y_pred_train_gini

print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train_gini)))


tk.Label(master, text="Number of year  Experience").grid(row=0)
tk.Label(master,text="Employed?").grid(row=1)
tk.Label(master, text="Enter Number of Previous employers").grid(row=2)
tk.Label(master, text="Level of Education").grid(row=3)
tk.Label(master, text="From Top-tier school?").grid(row=4)
tk.Label(master, text="Interned in this company?:").grid(row=5)
e1 = tk.Entry(master)
e2 = tk.Entry(master)
e3 = tk.Entry(master)
e4 = tk.Entry(master)
e5 = tk.Entry(master)
e6 = tk.Entry(master)


e1.grid(row=0, column=1)
e2.grid(row=1, column=1)
e3.grid(row=2, column=1)
e4.grid(row=3, column=1)
e5.grid(row=4, column=1)
e6.grid(row=5, column=1)



def prediction():
    pList = []
    
    maxLengthList = 6
    while len(pList) < maxLengthList:
    
        pList.append(e1.get())
        pList.append(e2.get())
        pList.append(e3.get())
        pList.append(e4.get())
        pList.append(e5.get())
        pList.append(e6.get())
        print(pList)
        
        from sklearn.ensemble import RandomForestClassifier

        clf = RandomForestClassifier(n_estimators=50)
        clf = clf.fit(X, y)


        if (clf.predict([pList])) == 0:
            nhired=tk.Label(master,font=20,text="Candidate can not get Hired!").grid(row=6,column=0)
        else:
            hired=tk.Label(master,font=20,text="Candidate can get Hired!").grid(row=6,column=0)


tk.Button(master,text='Prediction',bg="green",fg="white", command=prediction).grid(row=9,column=0)
tk.Button(master,text='Close',bg="red",fg="white", command=master.destroy).grid(row=9,column=1)



master.mainloop()
# Out:
# Model accuracy score with criterion gini index: 1.0000
# Training-set accuracy score: 0.9000
# ['10', '1', '1', '1', '1', '0']
